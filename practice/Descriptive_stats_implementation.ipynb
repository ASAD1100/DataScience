# %%
#importing all required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#ignore the harmless warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# import the tips & penguins data
tips=sns.load_dataset('tips')
penguins=sns.load_dataset('penguins')

# %%
penguins['species'].value_counts().index
# Out:
# Index(['Adelie', 'Gentoo', 'Chinstrap'], dtype='object', name='species')

# %%
# plot the data vlaues in countplot
for cols in penguins.columns:
  if penguins[cols].dtype=='O':
    # print(cols)
    ax=sns.countplot(x=penguins[cols], color='blue',order=penguins[cols].value_counts(ascending=False).index)
    ax.bar_label(ax.containers[0])# [0] index here represents the position of the plot
    plt.show()

# %%
# Use 'tips' dataset and find the numerical summary

# %%
# missing values of the data
tips.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# data type check
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
tips.describe(percentiles=[0.25,0.5,0.75,0.95,0.99])
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# 95%     38.061000    5.195500    4.000000
# 99%     48.227000    7.214500    6.000000
# max     50.810000   10.000000    6.000000

# %%
for cols in tips.columns:
  if tips[cols].dtype=='category':
    # print(cols,tips[cols].dtypes)
    a=sns.countplot(x=tips[cols],color='skyblue')
    a.bar_label(a.containers[0])
    plt.show()

# %%
# check outliers in tips data
for cols in tips.columns:
  if tips[cols].dtype!='category':#dtype is used for numpy array
    # print(cols)
    sns.boxplot(tips[cols],orient='h')
    plt.show()
