# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Housing.csv')
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.shape
# Out:
# (545, 13)

# %%
# encoding the data
encoded_data =pd.get_dummies(data,dtype = 'int', drop_first = True)
encoded_data.columns = encoded_data.columns.str.replace('furnishingstatus_','')
encoded_data.columns = encoded_data.columns.str.replace('_yes','')
encoded_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  parking  mainroad  guestroom  \
# 0  13300000  7420         4          2        3        2         1          0
# 1  12250000  8960         4          4        4        3         1          0
# 2  12250000  9960         3          2        2        2         1          0
# 3  12215000  7500         4          2        2        3         1          0
# 4  11410000  7420         4          1        2        2         1          1
#
#    basement  hotwaterheating  airconditioning  prefarea  semi-furnished  \
# 0         0                0                1         1               0
# 1         0                0                1         0               0
# 2         1                0                0         1               1
# 3         1                0                1         1               0
# 4         1                0                1         0               0
#
#    unfurnished
# 0            0
# 1            0
# ...

# %%
# Longer syntax - for learning putpose
# Theoretical learning
train, test = train_test_split(encoded_data, test_size = 0.3, random_state = 42)# train size = 0.7

# dimension of the data after splitting
print('DIMENSION OF THE DATA SPLIT')
print('Training data dimension: ',train.shape)
print('Testing data dimension: ',test.shape)

# independent and dependent split for the training data
x_train_t = train.drop(['price'], axis = 1)  #independent
y_train_t = train['price']                    #dependent

# independent and dependent split for the testing data
x_test_t = test.drop(['price'],axis = 1)  #independent
y_test_t = test['price']                  #dependent

#dimension of the further split
print(' \nDIMENDION OF TE FURTHER SPLIT')
print('x_train data dimension: ',x_train_t.shape)
print('y_train data dimension: ',y_train_t.shape)
print('x_test data dimension: ',x_test_t.shape)
print('y_test data dimension: ',y_test_t.shape)
# Out:
# DIMENSION OF THE DATA SPLIT
# Training data dimension:  (381, 14)
# Testing data dimension:  (164, 14)
#
# DIMENDION OF TE FURTHER SPLIT
# x_train data dimension:  (381, 13)
# y_train data dimension:  (381,)
# x_test data dimension:  (164, 13)
# y_test data dimension:  (164,)

# %%
# Easy and more practical method

# separate the data into dependent and independent variables
x  = encoded_data.drop(['price'],axis = 1)
y  = encoded_data['price']

# train test split
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size = 0.3, random_state=42)

# dimension of the further split
print('\nDIMENDION OF TE FURTHER SPLIT')
print('x_train data dimension: ',x_train.shape)
print('y_train data dimension: ',y_train.shape)
print('x_test data dimension: ',x_test.shape)
print('y_test data dimension: ',y_test.shape)
# Out:
# DIMENDION OF TE FURTHER SPLIT
# x_train data dimension:  (381, 13)
# y_train data dimension:  (381,)
# x_test data dimension:  (164, 13)
# y_test data dimension:  (164,)

# %%
x_train.head()
# Out:
#      area  bedrooms  bathrooms  stories  parking  mainroad  guestroom  \
# 126  7160         3          1        1        2         1          0
# 363  3584         2          1        1        0         1          0
# 370  4280         2          1        1        2         1          0
# 31   7000         3          1        4        2         1          0
# 113  9620         3          1        1        2         1          0
#
#      basement  hotwaterheating  airconditioning  prefarea  semi-furnished  \
# 126         1                0                0         1               0
# 363         0                1                0         0               1
# 370         0                0                1         0               1
# 31          0                0                1         0               1
# 113         1                0                0         1               0
#
#      unfurnished
# 126            1
# 363            0
# 370            0
# 31             0
# ...
