# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor as vif

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Datasets/Housing.csv')
data.shape
# Out:
# (545, 13)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  ...  airconditioning parking prefarea furnishingstatus
# 0  13300000  7420         4          2  ...              yes       2      yes        furnished
# 1  12250000  8960         4          4  ...              yes       3       no        furnished
# 2  12250000  9960         3          2  ...               no       2      yes   semi-furnished
# 3  12215000  7500         4          2  ...              yes       3      yes        furnished
# 4  11410000  7420         4          1  ...              yes       2       no        furnished
#
# [5 rows x 13 columns]

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
sns.kdeplot(data['price'],fill = True)
plt.show()

# %%
for cols in data.columns:
  if data[cols].dtype == 'O':
    print(cols,':',data[cols].unique())
# Out:
# mainroad : ['yes' 'no']
# guestroom : ['no' 'yes']
# basement : ['no' 'yes']
# hotwaterheating : ['no' 'yes']
# airconditioning : ['yes' 'no']
# prefarea : ['yes' 'no']
# furnishingstatus : ['furnished' 'semi-furnished' 'unfurnished']

# %%
edata = pd.get_dummies(data,drop_first = True, dtype = 'int')
edata.columns = edata.columns.str.replace('_yes','')
edata.columns = edata.columns.str.replace('furnishingstatus_','')
edata.head()
# Out:
#       price  area  bedrooms  bathrooms  ...  airconditioning  prefarea  semi-furnished  unfurnished
# 0  13300000  7420         4          2  ...                1         1               0            0
# 1  12250000  8960         4          4  ...                1         0               0            0
# 2  12250000  9960         3          2  ...                0         1               1            0
# 3  12215000  7500         4          2  ...                1         1               0            0
# 4  11410000  7420         4          1  ...                1         0               0            0
#
# [5 rows x 14 columns]

# %%
train, test = train_test_split(edata, test_size = 0.2,random_state = 42)

train.head()
# Out:
#        price  area  bedrooms  bathrooms  ...  airconditioning  prefarea  semi-furnished  unfurnished
# 46   7525000  6000         3          2  ...                1         0               0            0
# 93   6300000  7200         3          2  ...                1         0               1            0
# 335  3920000  3816         2          1  ...                1         0               0            0
# 412  3430000  2610         3          1  ...                0         1               0            1
# 471  3010000  3750         3          1  ...                0         0               0            1
#
# [5 rows x 14 columns]

# %%
cols = ['price','area','bedrooms','bathrooms','stories','parking']
scaler = MinMaxScaler() # keeps the values between 0 -1
train[cols] = scaler.fit_transform(train[cols])
test[cols] = scaler.transform(test[cols])

train.head()
# Out:
#         price      area  bedrooms  ...  prefarea  semi-furnished  unfurnished
# 46   0.550000  0.298969       0.4  ...         0               0            0
# 93   0.433333  0.381443       0.4  ...         0               1            0
# 335  0.206667  0.148866       0.2  ...         0               0            0
# 412  0.160000  0.065979       0.4  ...         1               0            1
# 471  0.120000  0.144330       0.4  ...         0               0            1
#
# [5 rows x 14 columns]

# %%
# training
x_train = train.drop(['price'],axis = 1)
y_train = train['price']

# testing
x_test = test.drop(['price'], axis = 1)
y_test = test['price']

# %%
# simple linear model for area
# add constant
lr_data = sm.add_constant(x_train['area'])
print(lr_data.head())
# fit the data onto the ols model
lr_model = sm.OLS(y_train, lr_data).fit()
# Out:
#      const      area
# 46     1.0  0.298969
# 93     1.0  0.381443
# 335    1.0  0.148866
# 412    1.0  0.065979
# 471    1.0  0.144330

# %%
# model params
print(lr_model.params)
# Out:
# const    0.139496
# area     0.589940
# dtype: float64

# %%
# scatter plot
plt.scatter(x_train['area'],y_train)
plt.scatter(x_train['area'],0.589940*(x_train['area'])+0.139496)
plt.show()

# %%
# residual analysis
y_train_pred = lr_model.predict(lr_data)
res = y_train - y_train_pred

# kde plot for the residuals
sns.kdeplot(res,fill = True)
plt.show()

# %%
RSS = ((y_train - y_train_pred)**2).sum()
TSS = ((y_train - y_train.mean())**2).sum()
r_square = 1-(RSS/TSS)
print(round(r_square*100,2))
# Out:
# 28.5

# %%
print(lr_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.285
# Model:                            OLS   Adj. R-squared:                  0.283
# Method:                 Least Squares   F-statistic:                     173.0
# Date:                Mon, 17 Feb 2025   Prob (F-statistic):           1.75e-33
# Time:                        17:36:42   Log-Likelihood:                 234.19
# No. Observations:                 436   AIC:                            -464.4
# Df Residuals:                     434   BIC:                            -456.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1395      0.013     10.933      0.000       0.114       0.165
# area           0.5899      0.045     13.151      0.000       0.502       0.678
# ==============================================================================
# Omnibus:                       78.264   Durbin-Watson:                   1.894
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              156.475
# Skew:                           0.978   Prob(JB):                     1.05e-34
# Kurtosis:                       5.187   Cond. No.                         7.00
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
